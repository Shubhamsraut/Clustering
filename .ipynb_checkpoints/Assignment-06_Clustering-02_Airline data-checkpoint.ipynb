# %%
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sn

# %%
airline1 = pd.read_csv("EastWestAirlines.csv")
airline1
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %% [markdown]
# ### 1. EDA

# %%
airline1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
airline2 = airline1.drop(['ID#'],axis=1)
airline2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# ### 1. Hierarchical Clustering

# %%
# Standardize the data:
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return(x)

# %%
# (considering the numerical part of data)
airline2_norm = norm_func(airline2)
airline2_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# creating a dendrogram
dendrogram = sch.dendrogram(sch.linkage(airline2_norm ,method ='average'))

# %%
# create clusters
hc =  AgglomerativeClustering(n_clusters = 4, affinity = 'euclidean', linkage = 'average')
hc
# Out:
# AgglomerativeClustering(linkage='average', n_clusters=4)

# %%
# clusters for chart
y_hc =hc.fit_predict(airline2_norm)
y_hc
# Out:
# array([1, 1, 1, ..., 0, 1, 1], dtype=int64)

# %%
Clusters = pd.DataFrame(y_hc, columns = ['Clusters'])
Clusters
# Out:
#       Clusters
# 0            1
# 1            1
# 2            1
# 3            1
# 4            0
# ...        ...
# 3994         0
# 3995         0
# 3996         0
# 3997         1
# 3998         1
#
# [3999 rows x 1 columns]

# %%
airline2_norm['h_clusterid'] = y_hc

# %%
airline2_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# ### 2. K-means

# %%
# How to find optimum number of  cluster
#The K-means algorithm aims to choose centroids that minimise the inertia, or within-cluster sum-of-squares criterion:
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans

# %%
wcss = []
for r in range (1,11):
    kmeans = KMeans(n_clusters = r, random_state = 0)
    kmeans.fit(airline2_norm)
    wcss.append(kmeans.inertia_)
    
plt.plot(range(1,11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Build Cluster algorithm
from sklearn.cluster import KMeans
clusters_new =  KMeans (5, random_state = 42) # Random state --> checking that your results are stable across a number of different distinct random seeds. Popular integer random seeds are 0 and 42.
clusters_new.fit(airline2_norm)
# Out:
# KMeans(n_clusters=5, random_state=42)

# %%
clusters_new.labels_
# Out:
# array([4, 4, 4, ..., 2, 1, 1])

# %%
# Assign clusters to the data set
airline2_norm['kmeans_clusterid_new'] = clusters_new.labels_

# %%
#These are standardized values.
clusters_new.cluster_centers_
# Out:
# array([[4.73307413e-02, 2.61040063e-02, 3.91791045e-02, 1.64179104e-02,
#         2.23880597e-03, 3.30623633e-02, 1.19316210e-01, 3.12268524e-02,
#         5.60405520e-02, 5.23268034e-01, 1.00000000e+00, 3.33066907e-16],
#        [1.96298577e-02, 8.47087091e-03, 1.76499033e-02, 8.22050290e-03,
#         1.69245648e-03, 1.26405881e-02, 7.32648104e-02, 8.26467393e-03,
#         1.33024342e-02, 2.39941343e-01, 1.93423598e-03, 1.00386847e+00],
#        [6.36341128e-02, 1.77365489e-02, 7.28908189e-01, 6.20347395e-04,
#         6.51364764e-03, 1.72625803e-01, 2.33568007e-01, 2.17623027e-02,
#         3.83913105e-02, 5.86823055e-01, 1.00000000e+00, 2.22044605e-16],
#        [6.92418434e-02, 6.69742584e-03, 6.46370968e-01, 8.06451613e-04,
#         5.64516129e-03, 1.19644083e-01, 2.02231808e-01, 9.14053513e-03,
#         1.45769933e-02, 5.31904136e-01, 3.22580645e-03, 1.00645161e+00],
#        [3.03993842e-02, 8.05523590e-03, 3.04948216e-02, 9.78135788e-03,
# ...

# %%
airline2_norm.groupby('kmeans_clusterid_new').agg(['mean']).reset_index()
# Out:
#   kmeans_clusterid_new   Balance Qual_miles cc1_miles cc2_miles cc3_miles  \
#                             mean       mean      mean      mean      mean
# 0                    0  0.047331   0.026104  0.039179  0.016418  0.002239
# 1                    1  0.019630   0.008471  0.017650  0.008221  0.001692
# 2                    2  0.063634   0.017737  0.728908  0.000620  0.006514
# 3                    3  0.069242   0.006697  0.646371  0.000806  0.005645
# 4                    4  0.030399   0.008055  0.030495  0.009781  0.000288
#
#   Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12 Days_since_enroll  \
#          mean        mean              mean            mean              mean
# 0    0.033062    0.119316          0.031227        0.056041          0.523268
# 1    0.012641    0.073265          0.008265        0.013302          0.239941
# 2    0.172626    0.233568          0.021762        0.038391          0.586823
# ...

# %%
airline2_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# ### 3. DBSCAN

# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %%
airline2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Balance            3999 non-null   int64
#  1   Qual_miles         3999 non-null   int64
#  2   cc1_miles          3999 non-null   int64
#  3   cc2_miles          3999 non-null   int64
#  4   cc3_miles          3999 non-null   int64
#  5   Bonus_miles        3999 non-null   int64
#  6   Bonus_trans        3999 non-null   int64
#  7   Flight_miles_12mo  3999 non-null   int64
#  8   Flight_trans_12    3999 non-null   int64
#  9   Days_since_enroll  3999 non-null   int64
#  10  Award?             3999 non-null   int64
# dtypes: int64(11)
# memory usage: 343.8 KB

# %%
airline3 = airline2.iloc[:,1:11]
airline3
# Out:
#       Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  Bonus_trans  \
# 0              0          1          1          1          174            1
# 1              0          1          1          1          215            2
# 2              0          1          1          1         4123            4
# 3              0          1          1          1          500            1
# 4              0          4          1          1        43300           26
# ...          ...        ...        ...        ...          ...          ...
# 3994           0          1          1          1         8525            4
# 3995           0          1          1          1          981            5
# 3996           0          3          1          1        25447            8
# 3997           0          1          1          1          500            1
# 3998           0          1          1          1            0            0
#
# ...

# %%
airline3.values
# Out:
# array([[   0,    1,    1, ...,    0, 7000,    0],
#        [   0,    1,    1, ...,    0, 6968,    0],
#        [   0,    1,    1, ...,    0, 7034,    0],
#        ...,
#        [   0,    3,    1, ...,    0, 1402,    1],
#        [   0,    1,    1, ...,    1, 1401,    0],
#        [   0,    1,    1, ...,    0, 1398,    0]], dtype=int64)

# %%
stscaler = StandardScaler().fit(airline3.values)
x = stscaler.transform(airline3.values)

# %%
x
# Out:
# array([[-0.18629869, -0.76957841, -0.09824189, ..., -0.36216787,
#          1.39545434, -0.7669193 ],
#        [-0.18629869, -0.76957841, -0.09824189, ..., -0.36216787,
#          1.37995704, -0.7669193 ],
#        [-0.18629869, -0.76957841, -0.09824189, ..., -0.36216787,
#          1.41192021, -0.7669193 ],
#        ...,
#        [-0.18629869,  0.68312117, -0.09824189, ..., -0.36216787,
#         -1.31560393,  1.30391816],
#        [-0.18629869, -0.76957841, -0.09824189, ..., -0.09850333,
#         -1.31608822, -0.7669193 ],
#        [-0.18629869, -0.76957841, -0.09824189, ..., -0.36216787,
#         -1.31754109, -0.7669193 ]])

# %%
dbscan = DBSCAN(eps=2,min_samples=4)
dbscan.fit(x)
# Out:
# DBSCAN(eps=2, min_samples=4)

# %%
#Noisy samples given the label--> -1.
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
cl =pd.DataFrame(dbscan.labels_,columns=['DBSCAN_cluster'])

# %%
cl
# Out:
#       DBSCAN_cluster
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  1
# ...              ...
# 3994               1
# 3995               1
# 3996               1
# 3997               0
# 3998               0
#
# [3999 rows x 1 columns]

# %%
pd.concat([airline3,cl],axis=1)
# Out:
#       Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  Bonus_trans  \
# 0              0          1          1          1          174            1
# 1              0          1          1          1          215            2
# 2              0          1          1          1         4123            4
# 3              0          1          1          1          500            1
# 4              0          4          1          1        43300           26
# ...          ...        ...        ...        ...          ...          ...
# 3994           0          1          1          1         8525            4
# 3995           0          1          1          1          981            5
# 3996           0          3          1          1        25447            8
# 3997           0          1          1          1          500            1
# 3998           0          1          1          1            0            0
#
# ...

# %%
pd.concat([airline2_norm,cl],axis=1)
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...
